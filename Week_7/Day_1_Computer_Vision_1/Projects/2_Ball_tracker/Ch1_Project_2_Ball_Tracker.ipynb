# %% [markdown]
# # Ball Tracker

# %% [markdown]
# ## Level 1
#
# 1. Given an image with a ball on it isolate the ball

# %%
#Import the libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import ImageFont, ImageDraw, Image

# %%
def showImg(img,title= ''):
    plt.figure(figsize = (10,5));
    plt.title(title)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

def showGrayScaleImg(img,title= ''):
    plt.figure(figsize = (10,5));
    plt.title(title)
    plt.imshow(img, cmap='gray')

# %%
img = cv2.imread('ball.jpg')
showImg(img)

# %%
#set the lower and upper bound
lower_range = (90,0,20)
upper_range = (130,255,255)

#create hsv version of the image
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) #ya no ocupo esto por que ya lo habia creado

#create copy for the masked image
masked_img = np.copy(img)

#define the mask
mask = cv2.inRange(hsv,lower_range,upper_range)

#aplly the mask
masked_img[mask == 0 ] = [0,0,0]

#plot
plt.figure(figsize = (10,5));
plt.imshow(cv2.cvtColor(masked_img,cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Level 2 (in process)
#
# 1. Make it track a ball in real time (either with a video or a webcam)

# %% [markdown]
# ## Level 3 (in process)
#
# 1. Can you make it track two or more different color balls at the same time?
