# %% [markdown]
# # Cars detector

# %% [markdown]
# ## Level 1
#
# 1. Create a classifier to detect cars in an image
# 2. If at least one car was detected write Car Detected (in Green) on top of the image, otherwise write No car detected (in Red)
# 3. Save the image to disk
# 4. Show the image result inside the notebook

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def showImg(img, title = ''):
    plt.figure(figsize = (20,15));
    plt.title(title)
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

def showGrayScaleImg(img, title = ''):
    plt.figure(figsize = (20,15));
    plt.title(title)
    plt.imshow(img, cmap='gray')

all_contours = -1
green = (0,255,0)
thickness = 2

new_img = cv2.UMat(cv2.IMREAD_COLOR)

# %%
image = cv2.imread('cars.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Load Template image
template = cv2.imread('car_template.jpg',0)

result = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

#Create Bounding Box
top_left = max_loc
bottom_right = (top_left[0] + 50, top_left[1] + 50)
cv2.rectangle(image, top_left, bottom_right, (0,255,0), 3)

showImg(image)
showImg(template)

# %%
image = cv2.imread('cars3.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Load Template image
template = cv2.imread('car_template3.jpg',0)

result = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

#Create Bounding Box
top_left = max_loc
bottom_right = (top_left[0] + 50, top_left[1] + 50)
cv2.rectangle(image, top_left, bottom_right, (0,255,0), 3)

showImg(image)
showImg(template)

# %% [markdown]
# ## Level 2
#
# 1. Make it work with a video0
# 1. Put a bounding box around the cars detected

# %% [markdown]
# ## Level 3
#
# 1. Get a higher resolution video and extract the car plates and save them to disk
