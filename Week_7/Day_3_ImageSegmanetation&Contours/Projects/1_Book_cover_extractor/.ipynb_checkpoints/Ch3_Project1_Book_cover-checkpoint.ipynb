# %% [markdown]
# # Book cover extractor

# %% [markdown]
# ## Level 1
#
# 1. From a given picture detect the book on the image and draw a box around it
# 1. Crop the book from the picture
# 1. Transform the book perspective to show it as a 2D image (to see the proper book cover)
# 1. If there is more than a book in the image make sure all books are extracted

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def showImg(img,title= ''):
    plt.figure(figsize = (10,5));
    plt.title(title)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

def showGrayScaleImg(img,title= ''):
    plt.figure(figsize = (10,5));
    plt.title(title)
    plt.imshow(img, cmap='gray')

# %%
book = cv2.imread('book.jpg')
showImg(book)

# %%
template = cv2.imread('booktemplate.jpg')
showImg(template)

# %%
all_contours = -1
green = (0,255,0)
thickness = 2

ret, thresh = cv2.threshold(template,127,255,cv2.THRESH_BINARY_INV)
showImg(thresh)

gray_book = cv2.cvtColor(thresh, cv2.COLOR_BGR2GRAY)

contours, hierarchy = cv2.findContours(gray_book,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

sorted_contours = sorted(contours, key= cv2.contourArea, reverse=True)

template_contour = contours[0]

cv2.drawContours(template,template_contour,all_contours,green,thickness)
showImg(template)

# %%
template = cv2.imread('booktemplate.jpg')
showImg(template)

ret, thresh = cv2.threshold(template,127,255,cv2.THRESH_BINARY_INV)
showImg(thresh)


gray_book = cv2.cvtColor(thresh, cv2.COLOR_BGR2GRAY)

contours, hierarchy = cv2.findContours(gray_book,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

sorted_contours = sorted(contours, key= cv2.contourArea, reverse=True)

template_contour = contours[0]

cv2.drawContours(template,template_contour,all_contours,green,thickness)
showImg(template)

book1 = cv2.imread('book.jpg',0)
book = cv2.imread('book.jpg')
showImg(book)

#blur = cv2.GaussianBlur(star1,(5,5),0)
ret, thresh1 = cv2.threshold(book1,127,255,cv2.THRESH_BINARY)
showImg(thresh1)

target_contours,hierarchy = cv2.findContours(thresh1,cv2.RETR_LIST,cv2.CHAIN_APPROX_NONE)

for contour in target_contours:
    match = cv2.matchShapes(template_contour,contour,1,0.0)
    if match < 0.50:
        cv2.drawContours(book,contour,all_contours,green,thickness)
        showImg(book)
# Out:
# C:\Users\ana.duran\AppData\Local\Continuum\anaconda3\envs\exercisew3d1\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
