# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig =plt.figure()
fig.add_subplot(2, 2, 1) # 2 rows, 2 cols, first element
fig.add_subplot(2, 2, 4) # 2 rows, 2 cols, last element

# %%
fig =plt.figure()
ax =fig.add_subplot(1, 1, 1)

# %%
ax.set_xticks([-2, -1, 0, 1, 2])
ax.set_xticklabels(['-std2', '-std1', 'mean', 'std1', 'std2'])
# Out:
# [Text(0.0, 0, '-std2'),
#  Text(0.2, 0, '-std1'),
#  Text(0.4, 0, 'mean'),
#  Text(0.6000000000000001, 0, 'std1'),
#  Text(0.8, 0, 'std2')]

# %%
plt.scatter(np.random.normal(size=10), np.random.normal(size=10))

# %%
plt.plot(np.arange(-5, 6, 0.01), np.sin(np.arange(-5, 6, 0.01)))

# %%
plt.hist(np.random.normal(size=100))
# Out:
# (array([ 2.,  2., 15., 24., 17., 16., 11.,  9.,  2.,  2.]),
#  array([-2.58407359, -2.05624787, -1.52842216, -1.00059644, -0.47277072,
#          0.05505499,  0.58288071,  1.11070643,  1.63853215,  2.16635786,
#          2.69418358]),
#  <a list of 10 Patch objects>)

# %%
plt.pie([0.2, 0.3, 0.5])
# Out:
# ([<matplotlib.patches.Wedge at 0x273bedde470>,
#   <matplotlib.patches.Wedge at 0x273bedde908>,
#   <matplotlib.patches.Wedge at 0x273beddedd8>],
#  [Text(0.8899186877588753, 0.6465637858537406, ''),
#   Text(-0.64656382751384, 0.8899186574910392, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %%
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
df =pd.Series([0.1, 0.2, 0.3, 0.5]).plot(kind='hist')

# %%
from sklearn.ensemble import RandomForestClassifier
